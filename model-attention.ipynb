# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("./dataset_pre_processed.csv", index_col=0)
df
# Out:
#                           time_to_delivery_from_shipment  \
# order_purchase_timestamp
# 2017-01-05 11:56:06                             5.021111
# 2017-01-05 12:01:20                             5.969502
# 2017-01-05 12:06:36                             5.020463
# 2017-01-05 12:09:08                             5.005278
# 2017-01-05 12:11:23                             5.988623
# ...                                                  ...
# 2018-08-29 12:25:59                             1.382257
# 2018-08-29 14:18:23                             1.038831
# 2018-08-29 14:18:28                             0.917720
# 2018-08-29 14:52:00                             0.858322
# 2018-08-29 15:00:37                             0.976806
#
#                           time_to_delivery_from_order_approved  \
# order_purchase_timestamp
# 2017-01-05 11:56:06                                   6.044306
# 2017-01-05 12:01:20                                  10.502326
# 2017-01-05 12:06:36                                   9.513889
# 2017-01-05 12:09:08                                   9.499549
# 2017-01-05 12:11:23                                  10.515544
# ...                                                        ...
# 2018-08-29 12:25:59                                   1.425810
# 2018-08-29 14:18:23                                   1.079028
# 2018-08-29 14:18:28                                   1.098704
# 2018-08-29 14:52:00                                   1.063623
# 2018-08-29 15:00:37                                   1.050810
#
#                           time_to_delivery_from_order_purchased  \
# order_purchase_timestamp
# 2017-01-05 11:56:06                                    6.054155
# 2017-01-05 12:01:20                                   12.151134
# 2017-01-05 12:06:36                                   11.165810
# 2017-01-05 12:09:08                                   11.148854
# 2017-01-05 12:11:23                                   12.163275
# ...                                                         ...
# 2018-08-29 12:25:59                                    1.432269
# 2018-08-29 14:18:23                                    1.087870
# 2018-08-29 14:18:28                                    1.106979
# 2018-08-29 14:52:00                                    1.072905
# 2018-08-29 15:00:37                                    1.057627
#
#                           freight_value  shipment_distance
# order_purchase_timestamp
# 2017-01-05 11:56:06                8.72          11.609337
# 2017-01-05 12:01:20                8.72          11.609337
# 2017-01-05 12:06:36                8.72          13.076936
# 2017-01-05 12:09:08                8.72          13.076936
# 2017-01-05 12:11:23                8.72          13.076936
# ...                                 ...                ...
# 2018-08-29 12:25:59                9.20          18.854775
# 2018-08-29 14:18:23               16.43          10.343719
# 2018-08-29 14:18:28               15.39         431.976676
# 2018-08-29 14:52:00                8.33          10.312870
# 2018-08-29 15:00:37                8.76         140.915746
#
# [92475 rows x 5 columns]

# %%
# !pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in c:\users\victo\anaconda3\envs\ts_project\lib\site-packages (1.3.0)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\victo\anaconda3\envs\ts_project\lib\site-packages (from scikit-learn) (1.24.3)
# Requirement already satisfied: scipy>=1.5.0 in c:\users\victo\anaconda3\envs\ts_project\lib\site-packages (from scikit-learn) (1.11.1)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\victo\anaconda3\envs\ts_project\lib\site-packages (from scikit-learn) (1.3.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\victo\anaconda3\envs\ts_project\lib\site-packages (from scikit-learn) (3.1.0)

# %%
from sklearn.preprocessing import StandardScaler
import math

# %%
def split_train_test(data, test_size=0.2):
    train_size = 1 - test_size
    cohort = int(math.ceil(data.shape[0] * train_size))
    train = data[0:cohort]
    test =  data[cohort:]
    return train, test

# %%
data = df[["time_to_delivery_from_order_purchased", "freight_value", "shipment_distance"]]

train, test = split_train_test(data)
print(train.shape)
print(test.shape)
# Out:
# (73980, 3)
# (18495, 3)

# %%
def scale_data(data):
    scaler = StandardScaler()
    scaled_data = scaler.fit_transform(data)
    return scaled_data, scaler

# %%
X_train_scaled, X_train_scaler = scale_data(train)
X_train_y_scaled, X_train_y_scaler = scale_data(train[["time_to_delivery_from_order_purchased"]])
print(X_train_scaled.shape)
print(X_train_y_scaled.shape)
# Out:
# (73980, 3)
# (73980, 1)

# %%
hops = 100
n_records = X_train_scaled.shape[0]
n_cols = X_train_scaled.shape[1]
X_train = []
y_train = []

for i in range(hops, n_records):
    X_train.append(X_train_scaled[i -hops: i])
    y_train.append(X_train_y_scaled[i][0])

X_train, y_train = np.array(X_train), np.array(y_train)

# %%
print(X_train.shape)
print(y_train.shape)
# Out:
# (73880, 100, 3)
# (73880,)

# %%
X_train_shape = X_train.shape
X_train_shape
# Out:
# (73880, 100, 3)

# %%
#!pip install -U tensorflow
# !pip install attention
# Out:
# Collecting attention
#   Downloading attention-5.0.0-py3-none-any.whl (9.0 kB)
# Requirement already satisfied: numpy>=1.18.1 in c:\users\victo\anaconda3\envs\ts_project\lib\site-packages (from attention) (1.24.3)
# Requirement already satisfied: tensorflow>=2.1 in c:\users\victo\anaconda3\envs\ts_project\lib\site-packages (from attention) (2.13.0)
# Requirement already satisfied: tensorflow-intel==2.13.0 in c:\users\victo\anaconda3\envs\ts_project\lib\site-packages (from tensorflow>=2.1->attention) (2.13.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\victo\anaconda3\envs\ts_project\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow>=2.1->attention) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\victo\anaconda3\envs\ts_project\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow>=2.1->attention) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.1.21 in c:\users\victo\anaconda3\envs\ts_project\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow>=2.1->attention) (23.5.26)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\victo\anaconda3\envs\ts_project\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow>=2.1->attention) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\victo\anaconda3\envs\ts_project\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow>=2.1->attention) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\victo\anaconda3\envs\ts_project\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow>=2.1->attention) (3.9.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\victo\anaconda3\envs\ts_project\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow>=2.1->attention) (16.0.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\victo\anaconda3\envs\ts_project\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow>=2.1->attention) (3.3.0)
# Requirement already satisfied: packaging in c:\users\victo\anaconda3\envs\ts_project\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow>=2.1->attention) (23.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\victo\anaconda3\envs\ts_project\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow>=2.1->attention) (4.23.4)
# Requirement already satisfied: setuptools in c:\users\victo\anaconda3\envs\ts_project\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow>=2.1->attention) (68.0.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\victo\anaconda3\envs\ts_project\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow>=2.1->attention) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\victo\anaconda3\envs\ts_project\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow>=2.1->attention) (2.3.0)
# Requirement already satisfied: typing-extensions<4.6.0,>=3.6.6 in c:\users\victo\anaconda3\envs\ts_project\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow>=2.1->attention) (4.5.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\victo\anaconda3\envs\ts_project\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow>=2.1->attention) (1.15.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\victo\anaconda3\envs\ts_project\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow>=2.1->attention) (1.56.0)
# Requirement already satisfied: tensorboard<2.14,>=2.13 in c:\users\victo\anaconda3\envs\ts_project\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow>=2.1->attention) (2.13.0)
# Requirement already satisfied: tensorflow-estimator<2.14,>=2.13.0 in c:\users\victo\anaconda3\envs\ts_project\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow>=2.1->attention) (2.13.0)
# Requirement already satisfied: keras<2.14,>=2.13.1 in c:\users\victo\anaconda3\envs\ts_project\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow>=2.1->attention) (2.13.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\victo\anaconda3\envs\ts_project\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow>=2.1->attention) (0.31.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\victo\anaconda3\envs\ts_project\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.13.0->tensorflow>=2.1->attention) (0.40.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\victo\anaconda3\envs\ts_project\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow>=2.1->attention) (2.22.0)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in c:\users\victo\anaconda3\envs\ts_project\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow>=2.1->attention) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\victo\anaconda3\envs\ts_project\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow>=2.1->attention) (3.4.3)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\victo\anaconda3\envs\ts_project\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow>=2.1->attention) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\victo\anaconda3\envs\ts_project\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow>=2.1->attention) (0.7.1)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\victo\anaconda3\envs\ts_project\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow>=2.1->attention) (2.3.6)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\victo\anaconda3\envs\ts_project\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow>=2.1->attention) (5.3.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\victo\anaconda3\envs\ts_project\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow>=2.1->attention) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\victo\anaconda3\envs\ts_project\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow>=2.1->attention) (4.9)
# Requirement already satisfied: urllib3<2.0 in c:\users\victo\anaconda3\envs\ts_project\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow>=2.1->attention) (1.26.16)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\victo\anaconda3\envs\ts_project\lib\site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow>=2.1->attention) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\victo\anaconda3\envs\ts_project\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow>=2.1->attention) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\victo\anaconda3\envs\ts_project\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow>=2.1->attention) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\victo\anaconda3\envs\ts_project\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow>=2.1->attention) (2023.5.7)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\victo\anaconda3\envs\ts_project\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow>=2.1->attention) (2.1.3)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in c:\users\victo\anaconda3\envs\ts_project\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow>=2.1->attention) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\victo\anaconda3\envs\ts_project\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow>=2.1->attention) (3.2.2)
# Installing collected packages: attention
# Successfully installed attention-5.0.0

# %%
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout
from keras.callbacks import EarlyStopping
from attention import Attention

# %%
model = Sequential()
model.add(LSTM(units=64, return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2])))
model.add(Attention(units=32))
model.add(Dense(1))
model.compile(optimizer="adam", loss="mean_squared_error")
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 100, 64)           17408
#
#  attention (Attention)       (None, 32)                8192
#
#  dense (Dense)               (None, 1)                 33
#
# =================================================================
# Total params: 25633 (100.13 KB)
# Trainable params: 25633 (100.13 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
callback = EarlyStopping(monitor='loss', patience=3)
model.fit(X_train, y_train, epochs=1000, batch_size=32, workers=8, use_multiprocessing=True, callbacks=[callback])
# Out:
# Epoch 1/1000
# 2309/2309 [==============================] - 38s 16ms/step - loss: 0.9667
# Epoch 2/1000
# 2309/2309 [==============================] - 35s 15ms/step - loss: 0.9650
# Epoch 3/1000
# 2309/2309 [==============================] - 37s 16ms/step - loss: 0.9651
# Epoch 4/1000
# 2309/2309 [==============================] - 36s 16ms/step - loss: 0.9645
# Epoch 5/1000
# 2309/2309 [==============================] - 36s 16ms/step - loss: 0.9643
# Epoch 6/1000
# 2309/2309 [==============================] - 36s 16ms/step - loss: 0.9642
# Epoch 7/1000
# 2309/2309 [==============================] - 36s 16ms/step - loss: 0.9642
# Epoch 8/1000
# 2309/2309 [==============================] - 36s 16ms/step - loss: 0.9641
# Epoch 9/1000
# 2309/2309 [==============================] - 36s 16ms/step - loss: 0.9638
# Epoch 10/1000
# 2309/2309 [==============================] - 36s 16ms/step - loss: 0.9639
# Epoch 11/1000
# 2309/2309 [==============================] - 36s 16ms/step - loss: 0.9638
# Epoch 12/1000
# 2309/2309 [==============================] - 36s 16ms/step - loss: 0.9638
# Epoch 13/1000
# 2309/2309 [==============================] - 37s 16ms/step - loss: 0.9635
# Epoch 14/1000
# 2309/2309 [==============================] - 37s 16ms/step - loss: 0.9637
# Epoch 15/1000
# 2309/2309 [==============================] - 36s 16ms/step - loss: 0.9633
# Epoch 16/1000
# 2309/2309 [==============================] - 36s 16ms/step - loss: 0.9632
# Epoch 17/1000
# 2309/2309 [==============================] - 36s 16ms/step - loss: 0.9633
# Epoch 18/1000
# 2309/2309 [==============================] - 37s 16ms/step - loss: 0.9632
# Epoch 19/1000
# 2309/2309 [==============================] - 37s 16ms/step - loss: 0.9626
# Epoch 20/1000
# 2309/2309 [==============================] - 37s 16ms/step - loss: 0.9624
# Epoch 21/1000
# 2309/2309 [==============================] - 36s 16ms/step - loss: 0.9621
# Epoch 22/1000
# 2309/2309 [==============================] - 36s 16ms/step - loss: 0.9614
# Epoch 23/1000
# 2309/2309 [==============================] - 36s 16ms/step - loss: 0.9609
# Epoch 24/1000
# 2309/2309 [==============================] - 37s 16ms/step - loss: 0.9600
# Epoch 25/1000
# 2309/2309 [==============================] - 37s 16ms/step - loss: 0.9584
# Epoch 26/1000
1000
# 2309/2309 [==============================] - 39s 17ms/step - loss: 0.6068
# Epoch 126/1000
# 2309/2309 [==============================] - 40s 18ms/step - loss: 0.6115
# Epoch 127/1000
# 2309/2309 [==============================] - 40s 17ms/step - loss: 0.6079
# Epoch 128/1000
# 2309/2309 [==============================] - 39s 17ms/step - loss: 0.6122

# %%
df_full = pd.concat((train.iloc[-hops:], test), axis=0)
print(df_full.shape)
df_full.head()
# Out:
# (18595, 3)
#                           time_to_delivery_from_order_purchased  \
# order_purchase_timestamp
# 2018-05-26 10:08:31                                    9.385498
# 2018-05-26 10:10:47                                   10.244155
# 2018-05-26 10:35:01                                   19.546725
# 2018-05-26 10:54:41                                   18.238958
# 2018-05-26 11:33:28                                    9.163472
#
#                           freight_value  shipment_distance
# order_purchase_timestamp
# 2018-05-26 10:08:31               16.43          81.794361
# 2018-05-26 10:10:47               16.43         433.987729
# 2018-05-26 10:35:01               16.43        1341.069643
# 2018-05-26 10:54:41                9.77         646.201000
# 2018-05-26 11:33:28                7.39          74.111753

# %%
df_full = X_train_scaler.transform(df_full)
df_full.shape
# Out:
# (18595, 3)

# %%
hops = 100
n_records = df_full.shape[0]
n_cols = df_full.shape[1]
X_test = np.array([df_full[i - hops: i] for i in range(hops, n_records)])
print(X_test.shape)
# Out:
# (18495, 100, 3)

# %%
y_pred = model.predict(X_test)
y_pred
# Out:
# 578/578 [==============================] - 4s 6ms/step
# array([[ 1.1449125 ],
#        [-0.1370905 ],
#        [ 0.20610252],
#        ...,
#        [-0.2165668 ],
#        [-0.42714363],
#        [-0.39366072]], dtype=float32)

# %%
y_pred = X_train_y_scaler.inverse_transform(y_pred)
y_pred
# Out:
# array([[18.586195],
#        [10.851468],
#        [12.92206 ],
#        ...,
#        [10.371963],
#        [ 9.101486],
#        [ 9.303499]], dtype=float32)

# %%
y_pred.shape
# Out:
# (18495, 1)

# %%
df_preds = pd.DataFrame({"preds": y_pred.reshape((-1,))})
df_preds
# Out:
#            preds
# 0      18.586195
# 1      10.851468
# 2      12.922060
# 3      12.723883
# 4      15.003242
# ...          ...
# 18490  10.478419
# 18491  10.299925
# 18492  10.371963
# 18493   9.101486
# 18494   9.303499
#
# [18495 rows x 1 columns]

# %%
test_final = pd.concat((test.reset_index(drop=True), df_preds), axis=1)
test_final
# Out:
#        time_to_delivery_from_order_purchased  freight_value  \
# 0                                  19.087535          16.43
# 1                                  17.323530          27.76
# 2                                   6.146944          12.84
# 3                                  10.943565          23.50
# 4                                  11.407627          16.43
# ...                                      ...            ...
# 18490                               1.432269           9.20
# 18491                               1.087870          16.43
# 18492                               1.106979          15.39
# 18493                               1.072905           8.33
# 18494                               1.057627           8.76
#
#        shipment_distance      preds
# 0             433.987729  18.586195
# 1             807.707149  10.851468
# 2             320.865049  12.922060
# 3             602.004596  12.723883
# 4             209.575788  15.003242
# ...                  ...        ...
# 18490          18.854775  10.478419
# 18491          10.343719  10.299925
# 18492         431.976676  10.371963
# 18493          10.312870   9.101486
# 18494         140.915746   9.303499
#
# [18495 rows x 4 columns]

# %%
y_true = test_final["time_to_delivery_from_order_purchased"]
y_pred = test_final["preds"]

# %%
from sklearn.metrics import mean_absolute_percentage_error, mean_squared_error, mean_absolute_error
mape = mean_absolute_percentage_error(y_true, y_pred)
mse = mean_squared_error(y_true, y_pred)
mae = mean_absolute_error(y_true, y_pred)
print(f"MAPE: {mape}")
print(f"MSE: {mse}")
print(f"MAE: {mae}")
# Out:
# MAPE: 0.8200001066094984
# MSE: 32.12832605846582
# MAE: 4.30905814086687

# %%
# import plotly.express as px
# fig = px.line(test_final, x=test_final["time_to_delivery_from_order_purchased"], y=test_final["time_to_delivery_from_order_purchased"])
# fig.add_scatter(x=test_final["time_to_delivery_from_order_purchased"], y=test_final["pred"])
# fig.show()
